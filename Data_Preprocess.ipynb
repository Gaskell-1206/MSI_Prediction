# %%
import numpy as np
import pandas as pd
from pathlib import Path
from matplotlib import pyplot as plt

# %% [markdown]
# # Store Test MSI

# %%
# Import dataset
file_path = Path('ex_data/CRC_DX_data_set/CRC_DX_Test_Split/CRC_DX_TEST_MSIMUT - test images')
file_list = list(file_path.glob('**/*'))
len(file_list)
# Out:
# 12846

# %%
file_df = pd.DataFrame()
for file in file_list:
    file_parts = file.parts
    file_dict = {
        'data_set' : file_parts[1].split('_')[0],
        'train_test' : file_parts[2],
        'label' : "MSS" if "MSS" in file_parts[3] else "MSI",
        'img_name': file_parts[4],
        'slice_id' : file_parts[4].split('-',2)[1],
        'subject_id' : file_parts[4].split('-',2)[2].split('.')[0]
    }
    file_df = file_df.append(file_dict,ignore_index=True)
file_df
# Out:
#       data_set         train_test label  \
# 0          CRC  CRC_DX_Test_Split   MSI
# 1          CRC  CRC_DX_Test_Split   MSI
# 2          CRC  CRC_DX_Test_Split   MSI
# 3          CRC  CRC_DX_Test_Split   MSI
# 4          CRC  CRC_DX_Test_Split   MSI
# ...        ...                ...   ...
# 12841      CRC  CRC_DX_Test_Split   MSI
# 12842      CRC  CRC_DX_Test_Split   MSI
# 12843      CRC  CRC_DX_Test_Split   MSI
# 12844      CRC  CRC_DX_Test_Split   MSI
# 12845      CRC  CRC_DX_Test_Split   MSI
#
#                                            img_name      slice_id  \
# 0      blk-ADPPCPKAFCGC-TCGA-WS-AB45-01Z-00-DX1.png  ADPPCPKAFCGC
# 1      blk-DTLMKTVDTCVF-TCGA-AY-6197-01Z-00-DX1.png  DTLMKTVDTCVF
# 2      blk-QSFRKKPKRIWT-TCGA-AY-6197-01Z-00-DX1.png  QSFRKKPKRIWT
# 3      blk-WWAIEFAPNTPN-TCGA-G4-6586-01Z-00-DX1.png  WWAIEFAPNTPN
# 4      blk-ALVNHTQSQTCK-TCGA-G4-6586-01Z-00-DX1.png  ALVNHTQSQTCK
# ...                                             ...           ...
# ...

# %%
file_df.to_csv('ex_data/CRC_DX_data_set/CRC_DX_Lib/CRC_DX_TEST_MSIMUT.csv',index=False)

# %% [markdown]
# # Store Test MSS

# %%
# Import dataset
file_path = Path('./ex_data/CRC_DX_data_set/CRC_DX_Test_Split/CRC_DX_TEST_MSS - test images')
file_list = list(file_path.glob('**/*'))
len(file_list)
# Out:
# 34257

# %%
file_df = pd.DataFrame()
for file in file_list:
    file_parts = file.parts
    file_dict = {
        'data_set' : file_parts[1].split('_')[0],
        'train_test' : file_parts[2],
        'label' : "MSS" if "MSS" in file_parts[3] else "MSI",
        'img_name': file_parts[4],
        'slice_id' : file_parts[4].split('-',2)[1],
        'subject_id' : file_parts[4].split('-',2)[2].split('.')[0]
    }
    file_df = file_df.append(file_dict,ignore_index=True)
file_df
# Out:
#       data_set         train_test label  \
# 0          CRC  CRC_DX_Test_Split   MSS
# 1          CRC  CRC_DX_Test_Split   MSS
# 2          CRC  CRC_DX_Test_Split   MSS
# 3          CRC  CRC_DX_Test_Split   MSS
# 4          CRC  CRC_DX_Test_Split   MSS
# ...        ...                ...   ...
# 34252      CRC  CRC_DX_Test_Split   MSS
# 34253      CRC  CRC_DX_Test_Split   MSS
# 34254      CRC  CRC_DX_Test_Split   MSS
# 34255      CRC  CRC_DX_Test_Split   MSS
# 34256      CRC  CRC_DX_Test_Split   MSS
#
#                                            img_name      slice_id  \
# 0      blk-DFHGAPNDVCFS-TCGA-AZ-6599-01Z-00-DX1.png  DFHGAPNDVCFS
# 1      blk-QQLIQSEGMPYH-TCGA-G4-6311-01Z-00-DX1.png  QQLIQSEGMPYH
# 2      blk-FQCYRDMKWNEL-TCGA-NH-A50T-01Z-00-DX1.png  FQCYRDMKWNEL
# 3      blk-APAYWPGHNMNS-TCGA-DC-6681-01Z-00-DX1.png  APAYWPGHNMNS
# 4      blk-GEAHWMWEWPGQ-TCGA-CM-6167-01Z-00-DX1.png  GEAHWMWEWPGQ
# ...                                             ...           ...
# ...

# %%
file_df.to_csv('ex_data/CRC_DX_data_set/CRC_DX_Lib/CRC_DX_TEST_MSS.csv', index=False)

# %% [markdown]
# # Store Val MSI

# %%
# Import dataset
file_path = Path('./ex_data/CRC_DX_data_set/CRC_DX_Val/CRC_DX_TEST_MSIMUT - validation images')
file_list = list(file_path.glob('**/*'))
len(file_list)
# Out:
# 15489

# %%
file_df = pd.DataFrame()
for file in file_list:
    file_parts = file.parts
    file_dict = {
        'data_set' : file_parts[1].split('_')[0],
        'train_test' : file_parts[2],
        'label' : "MSS" if "MSS" in file_parts[3] else "MSI",
        'img_name': file_parts[4],
        'slice_id' : file_parts[4].split('-',2)[1],
        'subject_id' : file_parts[4].split('-',2)[2].split('.')[0]
    }
    file_df = file_df.append(file_dict,ignore_index=True)
file_df
# Out:
#       data_set  train_test label  \
# 0          CRC  CRC_DX_Val   MSI
# 1          CRC  CRC_DX_Val   MSI
# 2          CRC  CRC_DX_Val   MSI
# 3          CRC  CRC_DX_Val   MSI
# 4          CRC  CRC_DX_Val   MSI
# ...        ...         ...   ...
# 15484      CRC  CRC_DX_Val   MSI
# 15485      CRC  CRC_DX_Val   MSI
# 15486      CRC  CRC_DX_Val   MSI
# 15487      CRC  CRC_DX_Val   MSI
# 15488      CRC  CRC_DX_Val   MSI
#
#                                            img_name      slice_id  \
# 0      blk-QYYYSGVKMYDK-TCGA-CK-6747-01Z-00-DX1.png  QYYYSGVKMYDK
# 1      blk-VAKGHDVEDIGV-TCGA-CM-4743-01Z-00-DX1.png  VAKGHDVEDIGV
# 2      blk-VLHQGRTNPIVC-TCGA-DC-6154-01Z-00-DX1.png  VLHQGRTNPIVC
# 3      blk-TGMQMMNWATYH-TCGA-CK-6746-01Z-00-DX1.png  TGMQMMNWATYH
# 4      blk-PRRPNNKWPTFL-TCGA-DC-6154-01Z-00-DX1.png  PRRPNNKWPTFL
# ...                                             ...           ...
# 15484  blk-DESEGWMFPFAI-TCGA-CM-4743-01Z-00-DX1.png  DESEGWMFPFAI
# ...

# %%
file_df.to_csv('ex_data/CRC_DX_data_set/CRC_DX_Lib/CRC_DX_VAL_MSIMUT.csv', index=False)

# %% [markdown]
# # Store Val MSS

# %%
# Import dataset
file_path = Path('./ex_data/CRC_DX_data_set/CRC_DX_Val/CRC_DX_TEST_MSS - validation images')
file_list = list(file_path.glob('**/*'))
len(file_list)
# Out:
# 36312

# %%
file_df = pd.DataFrame()
for file in file_list:
    file_parts = file.parts
    file_dict = {
        'data_set' : file_parts[1].split('_')[0],
        'train_test' : file_parts[2],
        'label' : "MSS" if "MSS" in file_parts[3] else "MSI",
        'img_name': file_parts[4],
        'slice_id' : file_parts[4].split('-',2)[1],
        'subject_id' : file_parts[4].split('-',2)[2].split('.')[0]
    }
    file_df = file_df.append(file_dict,ignore_index=True)
file_df
# Out:
#       data_set  train_test label  \
# 0          CRC  CRC_DX_Val   MSS
# 1          CRC  CRC_DX_Val   MSS
# 2          CRC  CRC_DX_Val   MSS
# 3          CRC  CRC_DX_Val   MSS
# 4          CRC  CRC_DX_Val   MSS
# ...        ...         ...   ...
# 36307      CRC  CRC_DX_Val   MSS
# 36308      CRC  CRC_DX_Val   MSS
# 36309      CRC  CRC_DX_Val   MSS
# 36310      CRC  CRC_DX_Val   MSS
# 36311      CRC  CRC_DX_Val   MSS
#
#                                            img_name      slice_id  \
# 0      blk-EINIFPCEDNRC-TCGA-AY-A71X-01Z-00-DX1.png  EINIFPCEDNRC
# 1      blk-SIFWGMFIYFGY-TCGA-AF-4110-01Z-00-DX1.png  SIFWGMFIYFGY
# 2      blk-RKTPLIDEDMGT-TCGA-AY-A71X-01Z-00-DX1.png  RKTPLIDEDMGT
# 3      blk-KGIRPQKSNPGG-TCGA-A6-6137-01Z-00-DX1.png  KGIRPQKSNPGG
# 4      blk-NTEAKQVCYTHH-TCGA-DM-A28K-01Z-00-DX1.png  NTEAKQVCYTHH
# ...                                             ...           ...
# 36307  blk-FGEFYRVPHEVT-TCGA-CM-5868-01Z-00-DX1.png  FGEFYRVPHEVT
# ...

# %%
file_df.to_csv('ex_data/CRC_DX_data_set/CRC_DX_Lib/CRC_DX_VAL_MSS.csv', index=False)

# %% [markdown]
# # Store Train MSI

# %%
# Import dataset
file_path = Path('./ex_data/CRC_DX_data_set/CRC_DX_Train/CRC_DX_TRAIN_MSIMUT - training images')
file_list = list(file_path.glob('**/*'))
len(file_list)
# Out:
# 46704

# %%
file_df = pd.DataFrame()
for file in file_list:
    file_parts = file.parts
    file_dict = {
        'data_set' : file_parts[1].split('_')[0],
        'train_test' : file_parts[2],
        'label' : "MSS" if "MSS" in file_parts[3] else "MSI",
        'img_name': file_parts[4],
        'slice_id' : file_parts[4].split('-',2)[1],
        'subject_id' : file_parts[4].split('-',2)[2].split('.')[0]
    }
    file_df = file_df.append(file_dict,ignore_index=True)
file_df
# Out:
#       data_set    train_test label  \
# 0          CRC  CRC_DX_Train   MSI
# 1          CRC  CRC_DX_Train   MSI
# 2          CRC  CRC_DX_Train   MSI
# 3          CRC  CRC_DX_Train   MSI
# 4          CRC  CRC_DX_Train   MSI
# ...        ...           ...   ...
# 46699      CRC  CRC_DX_Train   MSI
# 46700      CRC  CRC_DX_Train   MSI
# 46701      CRC  CRC_DX_Train   MSI
# 46702      CRC  CRC_DX_Train   MSI
# 46703      CRC  CRC_DX_Train   MSI
#
#                                            img_name      slice_id  \
# 0      blk-LSLNGLAMWWKC-TCGA-CM-4746-01Z-00-DX1.png  LSLNGLAMWWKC
# 1      blk-INHVPKDGPGHF-TCGA-AA-3821-01Z-00-DX1.png  INHVPKDGPGHF
# 2      blk-WQPGWWICDCKP-TCGA-AA-3811-01Z-00-DX1.png  WQPGWWICDCKP
# 3      blk-FKWSVYCYDRYA-TCGA-CM-6171-01Z-00-DX1.png  FKWSVYCYDRYA
# 4      blk-YGDWVAQDKEYP-TCGA-NH-A5IV-01Z-00-DX1.png  YGDWVAQDKEYP
# ...                                             ...           ...
# 46699  blk-MCHEHYDNQHKT-TCGA-AU-6004-01Z-00-DX1.png  MCHEHYDNQHKT
# ...

# %%
file_df.to_csv('ex_data/CRC_DX_data_set/CRC_DX_Lib/CRC_DX_TRAIN_MSIMUT.csv', index=False)

# %% [markdown]
# Store Train MSS

# %%
# Import dataset
file_path = Path('./ex_data/CRC_DX_data_set/CRC_DX_Train/CRC_DX_TRAIN_MSS - training images')
file_list = list(file_path.glob('**/*'))
len(file_list)
# Out:
# 46704

# %%
file_df = pd.DataFrame()
for file in file_list:
    file_parts = file.parts
    file_dict = {
        'data_set' : file_parts[1].split('_')[0],
        'train_test' : file_parts[2],
        'label' : "MSS" if "MSS" in file_parts[3] else "MSI",
        'img_name': file_parts[4],
        'slice_id' : file_parts[4].split('-',2)[1],
        'subject_id' : file_parts[4].split('-',2)[2].split('.')[0]
    }
    file_df = file_df.append(file_dict,ignore_index=True)
file_df
# Out:
#       data_set    train_test label  \
# 0          CRC  CRC_DX_Train   MSS
# 1          CRC  CRC_DX_Train   MSS
# 2          CRC  CRC_DX_Train   MSS
# 3          CRC  CRC_DX_Train   MSS
# 4          CRC  CRC_DX_Train   MSS
# ...        ...           ...   ...
# 46699      CRC  CRC_DX_Train   MSS
# 46700      CRC  CRC_DX_Train   MSS
# 46701      CRC  CRC_DX_Train   MSS
# 46702      CRC  CRC_DX_Train   MSS
# 46703      CRC  CRC_DX_Train   MSS
#
#                                            img_name      slice_id  \
# 0      blk-YMKIEPPKYFWL-TCGA-F4-6808-01Z-00-DX1.png  YMKIEPPKYFWL
# 1      blk-VCWNRVKAVMCV-TCGA-D5-6541-01Z-00-DX1.png  VCWNRVKAVMCV
# 2      blk-YGHASCWNVVSC-TCGA-F5-6813-01Z-00-DX1.png  YGHASCWNVVSC
# 3      blk-YSHSYKIDWWPG-TCGA-AA-3986-01Z-00-DX1.png  YSHSYKIDWWPG
# 4      blk-YVYVCAHTLAAC-TCGA-CM-6680-01Z-00-DX1.png  YVYVCAHTLAAC
# ...                                             ...           ...
# 46699  blk-TKHLYNTEGASI-TCGA-DC-6160-01Z-00-DX1.png  TKHLYNTEGASI
# ...

# %%
file_df.to_csv('ex_data/CRC_DX_data_set/CRC_DX_Lib/CRC_DX_TRAIN_MSS.csv', index=False)

# %% [markdown]
# # Merge Train, Val, Test

# %%
df1 = pd.read_csv('/Users/gaskell/Dropbox/Mac/Desktop/CBH/ex_data/CRC_DX_data_set/CRC_DX_Lib/CRC_DX_TRAIN_MSIMUT.csv')
df2 = pd.read_csv('/Users/gaskell/Dropbox/Mac/Desktop/CBH/ex_data/CRC_DX_data_set/CRC_DX_Lib/CRC_DX_TRAIN_MSS.csv')
df_train_all = df1.merge(df2, how='outer')
df_train_all
# Out:
#       data_set    train_test label  \
# 0          CRC  CRC_DX_Train   MSI
# 1          CRC  CRC_DX_Train   MSI
# 2          CRC  CRC_DX_Train   MSI
# 3          CRC  CRC_DX_Train   MSI
# 4          CRC  CRC_DX_Train   MSI
# ...        ...           ...   ...
# 93403      CRC  CRC_DX_Train   MSS
# 93404      CRC  CRC_DX_Train   MSS
# 93405      CRC  CRC_DX_Train   MSS
# 93406      CRC  CRC_DX_Train   MSS
# 93407      CRC  CRC_DX_Train   MSS
#
#                                            img_name      slice_id  \
# 0      blk-LSLNGLAMWWKC-TCGA-CM-4746-01Z-00-DX1.png  LSLNGLAMWWKC
# 1      blk-INHVPKDGPGHF-TCGA-AA-3821-01Z-00-DX1.png  INHVPKDGPGHF
# 2      blk-WQPGWWICDCKP-TCGA-AA-3811-01Z-00-DX1.png  WQPGWWICDCKP
# 3      blk-FKWSVYCYDRYA-TCGA-CM-6171-01Z-00-DX1.png  FKWSVYCYDRYA
# 4      blk-YGDWVAQDKEYP-TCGA-NH-A5IV-01Z-00-DX1.png  YGDWVAQDKEYP
# ...                                             ...           ...
# 93403  blk-TKHLYNTEGASI-TCGA-DC-6160-01Z-00-DX1.png  TKHLYNTEGASI
# ...

# %%
df_train_all = df_train_all.sort_values(['subject_id'], ignore_index=True)
df_train_all
# Out:
#       data_set    train_test label  \
# 0          CRC  CRC_DX_Train   MSS
# 1          CRC  CRC_DX_Train   MSS
# 2          CRC  CRC_DX_Train   MSS
# 3          CRC  CRC_DX_Train   MSS
# 4          CRC  CRC_DX_Train   MSS
# ...        ...           ...   ...
# 93403      CRC  CRC_DX_Train   MSS
# 93404      CRC  CRC_DX_Train   MSS
# 93405      CRC  CRC_DX_Train   MSS
# 93406      CRC  CRC_DX_Train   MSS
# 93407      CRC  CRC_DX_Train   MSS
#
#                                            img_name      slice_id  \
# 0      blk-WRPYYGCIQMDS-TCGA-3L-AA1B-01Z-00-DX1.png  WRPYYGCIQMDS
# 1      blk-WPDKHVYLMTSH-TCGA-3L-AA1B-01Z-00-DX1.png  WPDKHVYLMTSH
# 2      blk-YNVSWNTCEILY-TCGA-3L-AA1B-01Z-00-DX1.png  YNVSWNTCEILY
# 3      blk-YIGTPLCVVGPD-TCGA-3L-AA1B-01Z-00-DX1.png  YIGTPLCVVGPD
# 4      blk-WFHWHMAWYQWT-TCGA-3L-AA1B-01Z-00-DX1.png  WFHWHMAWYQWT
# ...                                             ...           ...
# 93403  blk-TPPVRHFVAREP-TCGA-SS-A7HO-01Z-00-DX1.png  TPPVRHFVAREP
# ...

# %%
df_train_all['subject_id'].value_counts()[df_train_all['subject_id'].value_counts() <= 10]
# Out:
# TCGA-AD-6899-01Z-00-DX1    10
# TCGA-EI-6917-01Z-00-DX1    10
# TCGA-D5-6539-01Z-00-DX1    10
# TCGA-CI-6622-01Z-00-DX1     7
# TCGA-D5-6898-01Z-00-DX1     7
# TCGA-D5-6920-01Z-00-DX1     6
# Name: subject_id, dtype: int64

# %%
key_list = list(df_train_all['subject_id'].value_counts()[df_train_all['subject_id'].value_counts() <= 10].keys())
key_list
# Out:
# ['TCGA-AD-6899-01Z-00-DX1',
#  'TCGA-EI-6917-01Z-00-DX1',
#  'TCGA-D5-6539-01Z-00-DX1',
#  'TCGA-CI-6622-01Z-00-DX1',
#  'TCGA-D5-6898-01Z-00-DX1',
#  'TCGA-D5-6920-01Z-00-DX1']

# %%
len(df_train_all[df_train_all['subject_id'].isin(key_list)])
# Out:
# 50

# %%
df_clear = df_train_all.drop(df_train_all[df_train_all['subject_id'].isin(key_list)].index)
df_clear
# Out:
#       data_set    train_test label  \
# 0          CRC  CRC_DX_Train   MSS
# 1          CRC  CRC_DX_Train   MSS
# 2          CRC  CRC_DX_Train   MSS
# 3          CRC  CRC_DX_Train   MSS
# 4          CRC  CRC_DX_Train   MSS
# ...        ...           ...   ...
# 93403      CRC  CRC_DX_Train   MSS
# 93404      CRC  CRC_DX_Train   MSS
# 93405      CRC  CRC_DX_Train   MSS
# 93406      CRC  CRC_DX_Train   MSS
# 93407      CRC  CRC_DX_Train   MSS
#
#                                            img_name      slice_id  \
# 0      blk-WRPYYGCIQMDS-TCGA-3L-AA1B-01Z-00-DX1.png  WRPYYGCIQMDS
# 1      blk-WPDKHVYLMTSH-TCGA-3L-AA1B-01Z-00-DX1.png  WPDKHVYLMTSH
# 2      blk-YNVSWNTCEILY-TCGA-3L-AA1B-01Z-00-DX1.png  YNVSWNTCEILY
# 3      blk-YIGTPLCVVGPD-TCGA-3L-AA1B-01Z-00-DX1.png  YIGTPLCVVGPD
# 4      blk-WFHWHMAWYQWT-TCGA-3L-AA1B-01Z-00-DX1.png  WFHWHMAWYQWT
# ...                                             ...           ...
# 93403  blk-TPPVRHFVAREP-TCGA-SS-A7HO-01Z-00-DX1.png  TPPVRHFVAREP
# ...

# %%
df_clear.to_csv('./ex_data/CRC_DX_data_set/CRC_DX_Lib/CRC_DX_TRAIN_ALL_Clear.csv',index=False)

# %%
df_clear['subject_id'].value_counts()
# Out:
# TCGA-CM-6171-01Z-00-DX1    4305
# TCGA-CM-4746-01Z-00-DX1    3360
# TCGA-NH-A5IV-01Z-00-DX1    2888
# TCGA-5M-AAT6-01Z-00-DX1    2621
# TCGA-QG-A5Z2-01Z-00-DX2    1985
#                            ...
# TCGA-CA-6717-01Z-00-DX1      18
# TCGA-EI-7004-01Z-00-DX1      17
# TCGA-D5-7000-01Z-00-DX1      17
# TCGA-D5-6922-01Z-00-DX1      12
# TCGA-DM-A1D8-01Z-00-DX1      12
# Name: subject_id, Length: 257, dtype: int64

# %%
df_train_all.to_csv('./ex_data/CRC_DX_data_set/CRC_DX_Lib/CRC_DX_TRAIN_ALL.csv',index=False)

# %%
df_train_all['subject_id'].value_counts()
# Out:
# TCGA-CM-6171-01Z-00-DX1    4305
# TCGA-CM-4746-01Z-00-DX1    3360
# TCGA-NH-A5IV-01Z-00-DX1    2888
# TCGA-5M-AAT6-01Z-00-DX1    2621
# TCGA-QG-A5Z2-01Z-00-DX2    1985
#                            ...
# TCGA-EI-6917-01Z-00-DX1      10
# TCGA-D5-6539-01Z-00-DX1      10
# TCGA-CI-6622-01Z-00-DX1       7
# TCGA-D5-6898-01Z-00-DX1       7
# TCGA-D5-6920-01Z-00-DX1       6
# Name: subject_id, Length: 263, dtype: int64

# %%
df1 = pd.read_csv('/Users/gaskell/Dropbox/Mac/Desktop/CBH/ex_data/CRC_DX_data_set/CRC_DX_Lib/CRC_DX_TEST_MSIMUT.csv')
df2 = pd.read_csv('/Users/gaskell/Dropbox/Mac/Desktop/CBH/ex_data/CRC_DX_data_set/CRC_DX_Lib/CRC_DX_TEST_MSS.csv')
df_test_all = df1.merge(df2, how='outer')
df_test_all
# Out:
#       data_set         train_test label  \
# 0          CRC  CRC_DX_Test_Split   MSI
# 1          CRC  CRC_DX_Test_Split   MSI
# 2          CRC  CRC_DX_Test_Split   MSI
# 3          CRC  CRC_DX_Test_Split   MSI
# 4          CRC  CRC_DX_Test_Split   MSI
# ...        ...                ...   ...
# 47098      CRC  CRC_DX_Test_Split   MSS
# 47099      CRC  CRC_DX_Test_Split   MSS
# 47100      CRC  CRC_DX_Test_Split   MSS
# 47101      CRC  CRC_DX_Test_Split   MSS
# 47102      CRC  CRC_DX_Test_Split   MSS
#
#                                            img_name      slice_id  \
# 0      blk-ADPPCPKAFCGC-TCGA-WS-AB45-01Z-00-DX1.png  ADPPCPKAFCGC
# 1      blk-DTLMKTVDTCVF-TCGA-AY-6197-01Z-00-DX1.png  DTLMKTVDTCVF
# 2      blk-QSFRKKPKRIWT-TCGA-AY-6197-01Z-00-DX1.png  QSFRKKPKRIWT
# 3      blk-WWAIEFAPNTPN-TCGA-G4-6586-01Z-00-DX1.png  WWAIEFAPNTPN
# 4      blk-ALVNHTQSQTCK-TCGA-G4-6586-01Z-00-DX1.png  ALVNHTQSQTCK
# ...                                             ...           ...
# ...

# %%
df_test_all.to_csv('./ex_data/CRC_DX_data_set/CRC_DX_Lib/CRC_DX_TEST_ALL.csv',index=False)

# %%
df1 = pd.read_csv('/Users/gaskell/Dropbox/Mac/Desktop/CBH/ex_data/CRC_DX_data_set/CRC_DX_Lib/CRC_DX_VAL_MSIMUT.csv')
df2 = pd.read_csv('/Users/gaskell/Dropbox/Mac/Desktop/CBH/ex_data/CRC_DX_data_set/CRC_DX_Lib/CRC_DX_VAL_MSS.csv')
df_val_all = df1.merge(df2, how='outer')
df_val_all
# Out:
#       data_set  train_test label  \
# 0          CRC  CRC_DX_Val   MSI
# 1          CRC  CRC_DX_Val   MSI
# 2          CRC  CRC_DX_Val   MSI
# 3          CRC  CRC_DX_Val   MSI
# 4          CRC  CRC_DX_Val   MSI
# ...        ...         ...   ...
# 51796      CRC  CRC_DX_Val   MSS
# 51797      CRC  CRC_DX_Val   MSS
# 51798      CRC  CRC_DX_Val   MSS
# 51799      CRC  CRC_DX_Val   MSS
# 51800      CRC  CRC_DX_Val   MSS
#
#                                            img_name      slice_id  \
# 0      blk-QYYYSGVKMYDK-TCGA-CK-6747-01Z-00-DX1.png  QYYYSGVKMYDK
# 1      blk-VAKGHDVEDIGV-TCGA-CM-4743-01Z-00-DX1.png  VAKGHDVEDIGV
# 2      blk-VLHQGRTNPIVC-TCGA-DC-6154-01Z-00-DX1.png  VLHQGRTNPIVC
# 3      blk-TGMQMMNWATYH-TCGA-CK-6746-01Z-00-DX1.png  TGMQMMNWATYH
# 4      blk-PRRPNNKWPTFL-TCGA-DC-6154-01Z-00-DX1.png  PRRPNNKWPTFL
# ...                                             ...           ...
# 51796  blk-FGEFYRVPHEVT-TCGA-CM-5868-01Z-00-DX1.png  FGEFYRVPHEVT
# ...

# %%
df_val_all.to_csv('./ex_data/CRC_DX_data_set/CRC_DX_Lib/CRC_DX_VAL_ALL.csv',index=False)

# %% [markdown]
# # CRC_MSIMUT_Train

# %%
CRC_MSIMUT_train_df = pd.read_csv('ex_data/CRC_DX_data_set/CRC_DX_CSV/CRC_DX_TRAIN_MSIMUT.csv')
len(CRC_MSIMUT_train_df)
# Out:
# 46704

# %%
CRC_MSIMUT_train_values = CRC_MSIMUT_train_df['subject_id'].value_counts()
CRC_MSIMUT_train_values
# Out:
# TCGA-CM-6171-01Z-00-DX1    4305
# TCGA-CM-4746-01Z-00-DX1    3360
# TCGA-NH-A5IV-01Z-00-DX1    2888
# TCGA-5M-AAT6-01Z-00-DX1    2621
# TCGA-QG-A5Z2-01Z-00-DX2    1985
# TCGA-CK-5913-01Z-00-DX1    1932
# TCGA-AD-6889-01Z-00-DX1    1921
# TCGA-QG-A5Z2-01Z-00-DX1    1697
# TCGA-CM-6674-01Z-00-DX1    1690
# TCGA-G4-6304-01Z-00-DX1    1649
# TCGA-AA-A01R-01Z-00-DX1    1454
# TCGA-AA-3947-01Z-00-DX1    1442
# TCGA-AA-A01P-01Z-00-DX1    1295
# TCGA-CM-6162-01Z-00-DX1    1226
# TCGA-CK-5916-01Z-00-DX1    1205
# TCGA-EI-6882-01Z-00-DX1    1198
# TCGA-F4-6570-01Z-00-DX1    1188
# TCGA-F4-6703-01Z-00-DX1    1184
# TCGA-CM-5861-01Z-00-DX1    1077
# TCGA-AM-5821-01Z-00-DX1     968
# TCGA-AA-3715-01Z-00-DX1     956
# TCGA-G4-6320-01Z-00-DX1     913
# TCGA-AU-6004-01Z-00-DX1     903
# TCGA-A6-6653-01Z-00-DX1     858
# TCGA-AA-A022-01Z-00-DX1     775
# TCGA-A6-3809-01Z-00-DX1     703
# TCGA-G4-6628-01Z-00-DX1     701
# TCGA-AA-3811-01Z-00-DX1     619
# TCGA-A6-5661-01Z-00-DX1     520
# ...

# %%
len3 = len(CRC_MSIMUT_train_values)
len3
# Out:
# 40

# %% [markdown]
# # CRC_MSS_Train

# %%
CRC_MSS_train_df = pd.read_csv('ex_data/CRC_DX_data_set/CRC_DX_CSV/CRC_DX_TRAIN_MSS.csv')

# %%
CRC_MSS_train_values = CRC_MSS_train_df['subject_id'].value_counts()
CRC_MSS_train_values
# Out:
# TCGA-5M-AATE-01Z-00-DX1    862
# TCGA-SS-A7HO-01Z-00-DX1    851
# TCGA-DY-A0XA-01Z-00-DX1    697
# TCGA-DM-A1DB-01Z-00-DX1    689
# TCGA-QG-A5YV-01Z-00-DX1    665
#                           ...
# TCGA-D5-6539-01Z-00-DX1     10
# TCGA-EI-6917-01Z-00-DX1     10
# TCGA-D5-6898-01Z-00-DX1      7
# TCGA-CI-6622-01Z-00-DX1      7
# TCGA-D5-6920-01Z-00-DX1      6
# Name: subject_id, Length: 223, dtype: int64

# %%
len4 = len(CRC_MSS_train_values)
len4
# Out:
# 223

# %% [markdown]
# # CRC_MSIMUT_Test

# %%
CRC_MSIMUT_test_df = pd.read_csv('ex_data/CRC_DX_data_set/CRC_DX_CSV/CRC_DX_TEST_MSIMUT.csv')

# %%
CRC_MSIMUT_test_values = CRC_MSIMUT_test_df['subject_id'].value_counts()
CRC_MSIMUT_test_values
# Out:
# TCGA-CM-4743-01Z-00-DX1    4064
# TCGA-D5-6530-01Z-00-DX1    3105
# TCGA-CK-6746-01Z-00-DX1    2438
# TCGA-AY-6197-01Z-00-DX1    2090
# TCGA-AZ-4615-01Z-00-DX1    2051
# TCGA-AZ-6598-01Z-00-DX1    1788
# TCGA-CK-6747-01Z-00-DX1    1765
# TCGA-AZ-6601-01Z-00-DX1    1569
# TCGA-DC-6154-01Z-00-DX1    1250
# TCGA-AA-3966-01Z-00-DX1     854
# TCGA-AD-6964-01Z-00-DX1     831
# TCGA-G4-6586-01Z-00-DX1     730
# TCGA-CK-4951-01Z-00-DX1     720
# TCGA-A6-2686-01Z-00-DX1     681
# TCGA-G4-6588-01Z-00-DX1     523
# TCGA-AA-3950-01Z-00-DX1     508
# TCGA-AD-A5EJ-01Z-00-DX1     507
# TCGA-AG-A02N-01Z-00-DX1     490
# TCGA-AA-3877-01Z-00-DX1     452
# TCGA-AD-5900-01Z-00-DX1     361
# TCGA-D5-6540-01Z-00-DX1     345
# TCGA-WS-AB45-01Z-00-DX1     343
# TCGA-AA-3833-01Z-00-DX1     303
# TCGA-G4-6302-01Z-00-DX1     247
# TCGA-G4-6309-01Z-00-DX1     240
# TCGA-D5-6928-01Z-00-DX1      80
# Name: subject_id, dtype: int64

# %%
len1 = len(CRC_MSIMUT_test_df['subject_id'].value_counts())
len1
# Out:
# 26

# %% [markdown]
# ## Validation

# %%
# Validation subjectid
CRC_MSIMUT_val_list = []
for i in range(0,len1,2):
    CRC_MSIMUT_val_list.append(CRC_MSIMUT_test_values.keys()[i])
print(len(CRC_MSIMUT_val_list))
CRC_MSIMUT_val_list
# Out:
# 13
# ['TCGA-CM-4743-01Z-00-DX1',
#  'TCGA-CK-6746-01Z-00-DX1',
#  'TCGA-AZ-4615-01Z-00-DX1',
#  'TCGA-CK-6747-01Z-00-DX1',
#  'TCGA-DC-6154-01Z-00-DX1',
#  'TCGA-AD-6964-01Z-00-DX1',
#  'TCGA-CK-4951-01Z-00-DX1',
#  'TCGA-G4-6588-01Z-00-DX1',
#  'TCGA-AD-A5EJ-01Z-00-DX1',
#  'TCGA-AA-3877-01Z-00-DX1',
#  'TCGA-D5-6540-01Z-00-DX1',
#  'TCGA-AA-3833-01Z-00-DX1',
#  'TCGA-G4-6309-01Z-00-DX1']

# %%
# get file_names with strings
import os
src_dir = "ex_data/CRC_DX_data_set/CRC_DX_Test/CRC_DX_TEST_MSIMUT - test images"
def get_file_names_with_strings(str_list, src_dir):
    full_list = os.listdir(src_dir)
    final_list = [nm for ps in str_list for nm in full_list if ps in nm]
    return final_list

CRC_MSIMUT_val_list_path = get_file_names_with_strings(CRC_MSIMUT_val_list, src_dir)
len(CRC_MSIMUT_val_list_path)
# Out:
# 15489

# %%
# Copy files into another list
import shutil
 
# path to source directory
src_dir = src_dir
 
# path to destination directory
dest_dir = 'ex_data/CRC_DX_data_set/CRC_DX_Val/CRC_DX_TEST_MSIMUT - validation images'

for fname in CRC_MSIMUT_val_list_path:
    # copying the files to the
    # destination directory
    shutil.copy2(os.path.join(src_dir,fname), dest_dir)

# %%
dest_dir = 'ex_data/CRC_DX_data_set/CRC_DX_Val/CRC_DX_TEST_MSIMUT - validation images'
files = os.listdir(dest_dir)
len(files)
# Out:
# 15489

# %% [markdown]
# ## Test

# %%
# Test subjectid
CRC_MSIMUT_test_list = []
for i in range(1,len1,2):
    CRC_MSIMUT_test_list.append(CRC_MSIMUT_test_values.keys()[i])
print(len(CRC_MSIMUT_test_list))
CRC_MSIMUT_test_list
# Out:
# 13
# ['TCGA-D5-6530-01Z-00-DX1',
#  'TCGA-AY-6197-01Z-00-DX1',
#  'TCGA-AZ-6598-01Z-00-DX1',
#  'TCGA-AZ-6601-01Z-00-DX1',
#  'TCGA-AA-3966-01Z-00-DX1',
#  'TCGA-G4-6586-01Z-00-DX1',
#  'TCGA-A6-2686-01Z-00-DX1',
#  'TCGA-AA-3950-01Z-00-DX1',
#  'TCGA-AG-A02N-01Z-00-DX1',
#  'TCGA-AD-5900-01Z-00-DX1',
#  'TCGA-WS-AB45-01Z-00-DX1',
#  'TCGA-G4-6302-01Z-00-DX1',
#  'TCGA-D5-6928-01Z-00-DX1']

# %%
src_dir = "ex_data/CRC_DX_data_set/CRC_DX_Test/CRC_DX_TEST_MSIMUT - test images"

CRC_MSIMUT_test_list_path = get_file_names_with_strings(CRC_MSIMUT_test_list, src_dir)
print(len(CRC_MSIMUT_test_list_path))
# Out:
# 12846

# %%
# path to source directory
src_dir = src_dir
 
# path to destination directory
dest_dir = 'ex_data/CRC_DX_data_set/CRC_DX_Test_Split/CRC_DX_TEST_MSIMUT - test images'

for fname in CRC_MSIMUT_test_list_path:
    # copying the files to the
    # destination directory
    shutil.copy2(os.path.join(src_dir,fname), dest_dir)

# %%
files = os.listdir(dest_dir)
len(files)
# Out:
# 12846

# %% [markdown]
# # CRC_MSS_Test

# %%
CRC_MSS_Test_df = pd.read_csv('ex_data/CRC_DX_data_set/CRC_DX_CSV/CRC_DX_TEST_MSS.csv')

# %%
CRC_MSS_test_values = CRC_MSS_Test_df['subject_id'].value_counts()
CRC_MSS_test_values
# Out:
# TCGA-AY-A71X-01Z-00-DX1    3914
# TCGA-DC-6681-01Z-00-DX1    3218
# TCGA-F5-6810-01Z-00-DX1    2754
# TCGA-F4-6460-01Z-00-DX1    2752
# TCGA-DC-6683-01Z-00-DX1    2504
#                            ...
# TCGA-G4-6315-01Z-00-DX1     125
# TCGA-CI-6624-01Z-00-DX1     123
# TCGA-AG-3887-01Z-00-DX1     118
# TCGA-AG-3726-01Z-00-DX1      35
# TCGA-AG-3727-01Z-00-DX1      27
# Name: subject_id, Length: 75, dtype: int64

# %%
len2 = len(CRC_MSS_Test_df['subject_id'].value_counts())
len2
# Out:
# 75

# %% [markdown]
# ## Validation

# %%
# Validation subjectid
CRC_MSS_val_list = []
for i in range(0,len2,2):
    CRC_MSS_val_list.append(CRC_MSS_test_values.keys()[i])
print(len(CRC_MSS_val_list))
CRC_MSS_val_list
# Out:
# 38
# ['TCGA-AY-A71X-01Z-00-DX1',
#  'TCGA-F5-6810-01Z-00-DX1',
#  'TCGA-DC-6683-01Z-00-DX1',
#  'TCGA-AZ-4315-01Z-00-DX1',
#  'TCGA-CM-5868-01Z-00-DX1',
#  'TCGA-CM-5864-01Z-00-DX1',
#  'TCGA-DM-A1D9-01Z-00-DX1',
#  'TCGA-A6-6137-01Z-00-DX1',
#  'TCGA-DC-6682-01Z-00-DX1',
#  'TCGA-AA-A02F-01Z-00-DX1',
#  'TCGA-AY-A8YK-01Z-00-DX1',
#  'TCGA-DM-A28K-01Z-00-DX1',
#  'TCGA-F5-6702-01Z-00-DX1',
#  'TCGA-CM-6172-01Z-00-DX1',
#  'TCGA-AA-A02O-01Z-00-DX1',
#  'TCGA-G4-6306-01Z-00-DX1',
#  'TCGA-AF-4110-01Z-00-DX1',
#  'TCGA-DM-A1D7-01Z-00-DX1',
#  'TCGA-AG-3898-01Z-00-DX1',
#  'TCGA-A6-3807-01Z-00-DX1',
#  'TCGA-AF-A56N-01Z-00-DX1',
#  'TCGA-AA-3679-01Z-00-DX1',
#  'TCGA-AH-6643-01Z-00-DX1',
#  'TCGA-AG-3896-01Z-00-DX1',
#  'TCGA-AA-3681-01Z-00-DX1',
#  'TCGA-AF-6136-01Z-00-DX1',
#  'TCGA-A6-5662-01Z-00-DX1',
#  'TCGA-AA-3875-01Z-00-DX1',
#  'TCGA-NH-A6GC-06Z-00-DX1',
#  'TCGA-AA-3968-01Z-00-DX1',
#  'TCGA-NH-A6GC-01Z-00-DX1',
#  'TCGA-A6-5657-01Z-00-DX1',
#  'TCGA-AA-3678-01Z-00-DX1',
# ...

# %%
src_dir = "ex_data/CRC_DX_data_set/CRC_DX_Test/CRC_DX_TEST_MSS - test images"
CRC_MSS_val_list_path = get_file_names_with_strings(CRC_MSS_val_list, src_dir)
len(CRC_MSS_val_list_path)
# Out:
# 36312

# %%
# path to source directory
src_dir = src_dir
 
# path to destination directory
dest_dir = 'ex_data/CRC_DX_data_set/CRC_DX_Val/CRC_DX_TEST_MSS - validation images'

for fname in CRC_MSS_val_list_path:
    # copying the files to the
    # destination directory
    shutil.copy2(os.path.join(src_dir,fname), dest_dir)

# %% [markdown]
# ## Test

# %%
# Test subjectid
CRC_MSS_test_list = []
for i in range(1,len2,2):
    CRC_MSS_test_list.append(CRC_MSS_test_values.keys()[i])
print(len(CRC_MSS_test_list))
CRC_MSS_test_list
# Out:
# 37
# ['TCGA-DC-6681-01Z-00-DX1',
#  'TCGA-F4-6460-01Z-00-DX1',
#  'TCGA-NH-A50T-01Z-00-DX1',
#  'TCGA-D5-5537-01Z-00-DX1',
#  'TCGA-EI-6514-01Z-00-DX1',
#  'TCGA-CM-5862-01Z-00-DX1',
#  'TCGA-AZ-6599-01Z-00-DX1',
#  'TCGA-F4-6809-01Z-00-DX1',
#  'TCGA-CM-6167-01Z-00-DX1',
#  'TCGA-AA-3856-01Z-00-DX1',
#  'TCGA-F5-6812-01Z-00-DX1',
#  'TCGA-CL-5917-01Z-00-DX1',
#  'TCGA-AZ-6600-01Z-00-DX1',
#  'TCGA-AA-3848-01Z-00-DX1',
#  'TCGA-CA-5256-01Z-00-DX1',
#  'TCGA-DC-4745-01Z-00-DX1',
#  'TCGA-CK-4950-01Z-00-DX1',
#  'TCGA-AH-6544-01Z-00-DX1',
#  'TCGA-CA-5255-01Z-00-DX1',
#  'TCGA-D5-6536-01Z-00-DX1',
#  'TCGA-AA-3818-01Z-00-DX1',
#  'TCGA-D5-6537-01Z-00-DX1',
#  'TCGA-G4-6311-01Z-00-DX1',
#  'TCGA-AG-A016-01Z-00-DX1',
#  'TCGA-AA-3837-01Z-00-DX1',
#  'TCGA-AA-3851-01Z-00-DX1',
#  'TCGA-CA-6716-01Z-00-DX1',
#  'TCGA-AA-A03F-01Z-00-DX1',
#  'TCGA-AG-3881-01Z-00-DX1',
#  'TCGA-AG-4015-01Z-00-DX1',
#  'TCGA-A6-2685-01Z-00-DX1',
#  'TCGA-AG-A02X-01Z-00-DX1',
#  'TCGA-AF-2687-01Z-00-DX1',
# ...

# %%
src_dir = "ex_data/CRC_DX_data_set/CRC_DX_Test/CRC_DX_TEST_MSS - test images"

CRC_MSS_test_list_path = get_file_names_with_strings(CRC_MSS_test_list, src_dir)
print(len(CRC_MSS_test_list_path))
# Out:
# 34257

# %%
# path to source directory
src_dir = src_dir
 
# path to destination directory
dest_dir = 'ex_data/CRC_DX_data_set/CRC_DX_Test_Split/CRC_DX_TEST_MSS - test images'

for fname in CRC_MSS_test_list_path:
    # copying the files to the
    # destination directory
    shutil.copy2(os.path.join(src_dir,fname), dest_dir)

# %%
files = os.listdir(dest_dir)
len(files)
# Out:
# 34257

# %% [markdown]
# # Create library file

# %%
CRC_DX_ALL = pd.read_csv('./ex_data/CRC_DX_data_set/CRC_DX_CSV/CRC_DX_ALL.csv').drop(columns=['Unnamed: 0'])
CRC_DX_ALL
# Out:
#        data_set label      slice_id               subject_id   train_test
# 0           CRC   MSI  ADPPCPKAFCGC  TCGA-WS-AB45-01Z-00-DX1  CRC_DX_Test
# 1           CRC   MSI  QYYYSGVKMYDK  TCGA-CK-6747-01Z-00-DX1  CRC_DX_Test
# 2           CRC   MSI  VAKGHDVEDIGV  TCGA-CM-4743-01Z-00-DX1  CRC_DX_Test
# 3           CRC   MSI  DTLMKTVDTCVF  TCGA-AY-6197-01Z-00-DX1  CRC_DX_Test
# 4           CRC   MSI  VLHQGRTNPIVC  TCGA-DC-6154-01Z-00-DX1  CRC_DX_Test
# ...         ...   ...           ...                      ...          ...
# 192307      CRC   MSS  YCAWFCGQRNEK  TCGA-D5-6537-01Z-00-DX1  CRC_DX_Test
# 192308      CRC   MSS  MQPRPYCCMMQP  TCGA-CM-5868-01Z-00-DX1  CRC_DX_Test
# 192309      CRC   MSS  FDGSAVSYHDMY  TCGA-CM-5868-01Z-00-DX1  CRC_DX_Test
# 192310      CRC   MSS  KHSHLIEEDRAD  TCGA-AA-A02O-01Z-00-DX1  CRC_DX_Test
# 192311      CRC   MSS  KATPTWCQNFMA  TCGA-F4-6460-01Z-00-DX1  CRC_DX_Test
#
# [192312 rows x 5 columns]

# %%
CRC_DX_ALL.iloc[0,:]
# Out:
# data_set                          CRC
# label                             MSI
# slice_id                 ADPPCPKAFCGC
# subject_id    TCGA-WS-AB45-01Z-00-DX1
# train_test                CRC_DX_Test
# Name: 0, dtype: object

# %%
root_dir = './ex_data/CRC_DX_data_set'
image_path = ''
